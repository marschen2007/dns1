# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import time
import dns.resolver

with open(r"C:\Users\Marchen\Desktop\dns.csv",'r') as f:
    alist = [line.rstrip() for line in f]

#output = open(r"C:\Users\Marchen\Desktop\dns-output.txt",'w')

for i in alist:
    try:
        answers = dns.resolver.query(i,'SOA')
    except Exception:
        pass
#    time.sleep(1)
#    for a in soa:
#        print(i)
#        print(a)
#        for j in soa
    for rdata in answers:
#       print(rdata.serial, rdata.rname)
        print(i,rdata.rname) 
#        if i not in rdata.rname:
#            print(i)
#       print(rdata.refresh, rdata.retry)
#       print(rdata.expire, rdata.minimum)
#        print(rdata.mname)
# Out:
# tssco.com.tw hostmaster.nsa.tssco.com.tw.
# afa.gov.tw .
# aftygh.gov.tw hostmaster.gtm.aftygh.gov.tw.
# allwin.com.tw tech.twnic.net.tw.
# ardentec.com postmaster.ns.ardentec.com.
# aseglobal.com koji_chen.
# asus.com dns_admin.asus.com.
# auo.com itts1.auo.com.
# bankchb.com ap12.yeh.chb.com.tw.
# bbintech.com support.name.com.
# bitoex.com dns.cloudflare.com.
# bli.gov.tw hostmaster.ns5.bli.gov.tw.
# bok.com.tw root.bok.com.tw.
# books.com.tw root.c29.books.com.tw.
# bot.com.tw 190840.mail.bot.com.tw.
# capital.com.tw g_itregisterinfo.capital.com.tw.
# cathaybk.com.tw hostmaster.pxdns02.cathaybk.com.tw.
# cathaylife.com.tw ns1.cathaylife.com.tw.
# cathaysec.com.tw admin.
# chinalife.com.tw yuan2626.chinalife.com.tw.
# cht.com.tw msadmin.cht.com.tw.
# chtglobal.com it.chtglobal.com.
# chungyo.net root.localhost.
# city.starq.com root.localhost.
# cns.net.tw hostmaster.
# cpami.gov.tw root.ns1.cpami.gov.tw.
# ctbcbank.com root.ns1.ctbcbank.com.
# ctbcbank.com root.ns1.ctbcbank.com.
# cwb.gov.tw netadm.cwb.gov.tw.
# dc-net.com.hk domain.dchl.org.
# delta.com.tw administrator.delta.com.tw.
# dgbas.gov.tw root.dgbas.gov.tw.
# dlinktw.com.tw itd.dlink.com.tw.
# dl-tek.com dns.jomax.net.
# easycard.com.tw dns.easycard.com.tw.
# edu.tw abuse.moe.edu.tw.
# egat.com.tw egat.com.tw.
# entrust.com.tw administrator.entrust.com.tw.
# eslitecorp.com eslitebooksse.eslite.com.tw.
# esunbank.com.tw shian-1763.email.esunbank.com.tw.
# esunsec.com.tw cyn-01989.esunbank.com.tw.
# evaair.com krischen.evaair.com.
# evergreen.com.tw hostmaster.domain.tld.
# existed hostmaster.domain.tld.
# fia.gov.tw fw.fia.gov.tw.
# fingu.com hostmaster.nameserver.
# fisc.com.tw eric_hsu.mail.fisc.com.tw.
# foxconn.com.tw jackyang.foxconn.com.
# fpg.com.tw administrator.fpg.com.tw.
# freeway.gov.tw log_admin.freeway.gov.tw.
# fubon.com root.fubon.com.
# fubon.com root.fubon.com.
# fubon.com root.fubon.com.
# fubon.com root.fubon.com.
# gamesoft.com hostmaster.gamesoft.com.
# gangutech.com admin.gangutech.com.
# garena.tw awsdns-hostmaster.amazon.com.
# golddeluxephil.com dns.jomax.net.
# gov.taipei root.dnssec1.taipei.gov.tw.
# happycashcard.com.tw sysop.vdns2.seed.net.tw.
# htc.com hostamaster.htc.com.
# htc.com hostmaster.htc.com.
# inventec.com admin.iec.inventec.
# itri.org.tw dnsbgp2.itri.org.tw.
# itri.org.tw dnsbgp2.itri.org.tw.
# jcic.org.tw hostmaster.f5-1.jcic.org.tw.
# jcic.org.tw hostmaster.f5-1.jcic.org.tw.
# jihsun.com.tw administrator.jihsun.com.tw.
# jkos.com abuse.digiage.com.tw.
# kao.com root.kao.com.
# key-enterprises.com hostmaster.plus.net.uk.
# kgi.com root.kgi.com.tw.
# kh.twport.com.tw root.kgi.com.tw.
# landbank.com.tw please_set_email.absolutely.nowhere.
# macronix.com.tw postmaster.dns211.macronix.com.tw.
# megabank.com.tw kane_chang.megabank.com.tw.
# megabank.com.tw kane_chang.megabank.com.tw.
# mmc.edu.tw hostmaster.mmc.edu.tw.
# mnd.gov.tw mnd.gov.tw.
# moe.gov.tw abuse.moe.edu.tw.
# moea.gov.tw abuse.moe.edu.tw.
# mof.gov.tw clhsu.mail.mof.gov.tw.
# mohw.gov.tw admin.mohw.gov.tw.
# motc.gov.tw root.motc-m.motc.gov.tw.
# nccc.com.tw hostmaster.3dns1.nccc.com.tw.
# nccc.com.tw hostmaster.3dns1.nccc.com.tw.
# nchu.edu.tw root.nchud1.nchu.edu.tw.
# ncku.edu.tw abuse.mail.ncku.edu.tw.
# ncsist.org.tw hostmaster.
# ncu.edu.tw abuse.ncu.edu.tw.
# novatek.com.tw hostmaster.novatek.com.tw.
# nuu.edu.tw abuse.nuu.edu.tw.
# o-bank.com hostmaster.dns.ibt.com.tw.
# orientsec.com.hk ns2.udomain.com.
# osc.com.tw root.dns.osc.com.tw.
# pchome.com.tw root.dns.pchome.com.tw.
# pchome.com.tw root.dns.pchome.com.tw.
# pegatroncorp.com hostmaster.dns1.pegatroncorp.com.
# pic.net.tw blanc.piinet.net.
# post.gov.tw felixccc.mail.post.gov.tw.
# prulife.com.tw hostmaster.prulife.intra.
# pscnet.com.tw etrade.mail.pscnet.com.tw.
# quantatw.com hostmaster.qrdcgtm.quantatw.com.
# railway.gov.tw hostmaster.railway.gov.tw.
# railway.gov.tw hostmaster.railway.gov.tw.
# scsb.com.tw root.scsb.com.tw.
# securities.sinopac.com root.scsb.com.tw.
# skbank.com.tw .
# skbank.com.tw .
# sltung.com.tw hostmaster.proxy.
# so-net.net.tw no.mail.to.me.sonet-tw.net.tw.
# spil.com.tw hostmaster.ns.spil.com.tw.
# sunnybank.com.tw s20783.sunnybank.com.tw.
# symphox.net dns.symphox.net.
# "synnex-grp.com dns.symphox.net.
#  nstld.verisign-grs.com.
# " nstld.verisign-grs.com.
# tcstock.com.tw sysinfo.tcstock.com.tw.
# tcte.edu.tw root.www.tcte.edu.tw.tcte.edu.tw.
# tdcc.com.tw andywu.tdcc.com.tw.
# tier.org.tw hostmaster.tier.org.tw.
# tii.org.tw admin.tii.org.tw.
# titansoft.com dns.cloudflare.com.
# tmu.edu.tw netgroup.tmu.edu.tw.
# tn.edu.tw abuse.tn.edu.tw.
# tomgroup.com info.wyith.net.
# tpex.org.tw harrishsu.tpex.org.tw.
# tradevan.com.tw root.tradevan.com.tw.
# tse.com.tw hostmaster.lb-ext-02-sinyi.twse.com.tw.tse.com.tw.
# tsmc.com.tw root.dns1.tsmc.com.tw.
# tstartel.com master\@tstartel.com.
# ttv.com.tw root.ns.ttv.com.tw.
# tw.cyberlink.com root.ns.ttv.com.tw.
# tw.gamania.com root.ns.ttv.com.tw.
# tw.nextmedia.com root.ns.ttv.com.tw.
# twca.com.tw maintain.twca.com.tw.
# twnch.org.tw root.twnch.org.tw.
# udngroup.com sp.udngroup.com.tw.
# uitox.com dns-admin.uitox.com.
# wanhai.com.tw hostmaster.wanhai.com.tw.
# wonderland.com.tw hostmaster.
# wra.gov.tw administrator.wra.gov.tw.
# www.swcb.gov.tw administrator.wra.gov.tw.
# xsg.com.tw dns.jomax.net.
# yuantabank.com.tw root.yuantabank.com.tw.
# yuantafutures.com.tw hostmaster.
# zurich.com dnsdhcp_admin_europe.zurich.com.
# synnex.com.tw admin.synnex.com.tw.
